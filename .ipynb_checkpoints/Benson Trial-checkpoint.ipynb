# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("Fare_Card_History_for_Metropolitan_Transportation_Authority__MTA___Beginning_2010.csv")

# %%
df["Station"] = df.Station.str.strip()
df['Fares']=df.iloc[:,4:].sum(axis=1, numeric_only=True)
def todate(test):
    return datetime.datetime.strptime(test, "%m/%d/%Y").date()

df['From Date2']=df['From Date'].apply(todate)
df['To Date2']=df['To Date'].apply(todate)

# %%
df['From Date2'] = pd.to_datetime(df['From Date'], infer_datetime_format=True)
df['To Date2'] = pd.to_datetime(df['To Date'], infer_datetime_format=True)
df.head()
# Out:
#     From Date     To Date Remote Station ID                     Station  \
# 0  02/13/2016  02/19/2016              R001            WHITEHALL STREET
# 1  02/13/2016  02/19/2016              R003               CYPRESS HILLS
# 2  02/13/2016  02/19/2016              R004  75TH STREET & ELDERTS LANE
# 3  02/13/2016  02/19/2016              R005  85TH STREET & FOREST PKWAY
# 4  02/13/2016  02/19/2016              R006         WOODHAVEN BOULEVARD
#
#    Full Fare  Senior Citizen / Disabled  \
# 0      46710                       1811
# 1       2793                        138
# 2       7229                        356
# 3       7998                        441
# 4       7641                        422
#
#    7 Day ADA Farecard Access System Unlimited  \
# 0                                         264
# 1                                          14
# 2                                          28
# 3                                          36
# 4                                          27
#
#    30 Day ADA Farecard Access System Unlimited  Joint Rail Road Ticket  \
# 0                                          756                     231
# 1                                           40                       0
# 2                                          102                       0
# 3                                          177                       4
# 4                                          149                       1
#
#    7 Day Unlimited    ...      Mail and Ride EZPass Express  \
# 0            21775    ...                              1202
# 1             2171    ...                                 6
# 2             5144    ...                                32
# 3             5407    ...                                51
# 4             6857    ...                                72
#
#    Mail and Ride Unlimited  Path 2 Trip  Airtran Full Fare  Airtran 30 Day  \
# 0                      470            0                843               0
# 1                        9            0                  7               0
# 2                       52            0                 75               0
# 3                       76            0                 70               0
# 4                       61            0                 64               0
#
#    Airtran 10 Trip  Airtran Monthly   Fares  From Date2   To Date2
# 0                0                0  107378  2016-02-13 2016-02-19
# 1                0                0    6527  2016-02-13 2016-02-19
# 2                0                0   17369  2016-02-13 2016-02-19
# 3                0                0   19636  2016-02-13 2016-02-19
# 4                0                0   20956  2016-02-13 2016-02-19
#
# [5 rows x 29 columns]

# %%
df2 =df[df['From Date2'].apply(lambda x : x.month==9)]
df2 =df2[df2['To Date2'].apply(lambda x : x.month==9)]
df2.head()
df2.columns
# Out:
# Index(['From Date', 'To Date', 'Remote Station ID', 'Station', 'Full Fare',
#        'Senior Citizen / Disabled',
#        '7 Day ADA Farecard Access System Unlimited',
#        '30 Day ADA Farecard Access System Unlimited', 'Joint Rail Road Ticket',
#        '7 Day Unlimited', '30 Day Unlimited',
#        '14 Day Reduced Fare Media Unlimited', '1 Day Unlimited',
#        '14 Day Unlimited', '7 Day Express Bus Pass', 'Transit Check Metrocard',
#        'LIB Special Senior', 'Rail Road Unlimited No Trade',
#        'Transit Check Metrocard Annual Metrocard',
#        'Mail and Ride EZPass Express', 'Mail and Ride Unlimited',
#        'Path 2 Trip', 'Airtran Full Fare', 'Airtran 30 Day', 'Airtran 10 Trip',
#        'Airtran Monthly', 'Fares', 'From Date2', 'To Date2'],
#       dtype='object')

# %%
len(df2.groupby(['Station']))
# Out:
# 515

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df2.groupby(['Station']).Fares.mean().sort_values(ascending=False).reset_index().head(20)
# Out:
#                         Station          Fares
# 0      14TH STREET-UNION SQUARE  631589.379310
# 1   59TH STREET/COLUMBUS CIRCLE  418800.689655
# 2      34TH STREET & 6TH AVENUE  343992.672414
# 3     86TH STREET-LEXINGTON AVE  337666.793103
# 4     47-50 STREETS/ROCKEFELLER  309273.310345
# 5    34TH STREET - PENN STATION  301025.931034
# 6      42ND STREET/TIMES SQUARE  295701.965517
# 7                    PARK PLACE  289990.379310
# 8     ROOSEVELT AVE/JACKSON HTS  283746.586207
# 9      42ND STREET & 8TH AVENUE  282434.603448
# 10                  MAIN STREET  279897.068966
# 11                FULTON STREET  255739.655172
# 12  42ND STREET & GRAND CENTRAL  254488.965517
# 13    WEST 4TH ST-WASHINGTON SQ  251541.896552
# 14       8TH AVENUE-14TH STREET  250187.862069
# 15       72ND STREET & BROADWAY  233609.896552
# 16     34TH STREET & 8TH AVENUE  228992.120690
# 17              BARCLAYS CENTER  226939.227273
# 18     42ND STREET & 6TH AVENUE  221474.862069
# 19         96TH STREET-BROADWAY  220554.310345

# %%
df2.groupby(['Station']).Fares.sum().sort_values(ascending=False).reset_index().head(20)
# Out:
#                         Station     Fares
# 0   42ND STREET & GRAND CENTRAL  22140540
# 1      34TH STREET & 6TH AVENUE  19951575
# 2      14TH STREET-UNION SQUARE  18316092
# 3      42ND STREET/TIMES SQUARE  17150714
# 4      42ND STREET & 8TH AVENUE  16381207
# 5      34TH STREET & 8TH AVENUE  13281543
# 6   59TH STREET/COLUMBUS CIRCLE  12145220
# 7   59TH STREET & LEXINGTON AVE  10217456
# 8     86TH STREET-LEXINGTON AVE   9792337
# 9     47-50 STREETS/ROCKEFELLER   8968926
# 10   34TH STREET - PENN STATION   8729752
# 11                   PARK PLACE   8409721
# 12    ROOSEVELT AVE/JACKSON HTS   8228651
# 13                  MAIN STREET   8117015
# 14                FULTON STREET   7416450
# 15                  WALL STREET   7397141
# 16    WEST 4TH ST-WASHINGTON SQ   7294715
# 17       8TH AVENUE-14TH STREET   7255448
# 18       72ND STREET & BROADWAY   6774687
# 19             LEXINGTON AVENUE   6621149

# %%
df3 = pd.DataFrame()

df3['Fares_std']=df2.groupby(['Station']).Fares.std()
df3['Fares_sum']=df2.groupby(['Station']).Fares.sum()
df3['Fares_mean']=df2.groupby(['Station']).Fares.mean()
df3.head()

import matplotlib.pyplot as plt
plt.scatter(df3.Fares_sum, df3.Fares_mean)
plt.xlabel('Fares Sum')
plt.ylabel('Fares Mean')
plt.show()

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.plotting import ColumnDataSource
from bokeh.models import HoverTool

stations = list(df2['Station'].unique())

hover_tool = HoverTool(tooltips =[
    ('Station', '@Station'),
    ('Sum', '@Fares_sum'),
    ('Mean','@{Fares_mean}')
])

plot = figure()
data = ColumnDataSource(df3)
plot.circle(x = 'Fares_sum', y = 'Fares_mean', source = data, alpha=0.5)
plot.add_tools(hover_tool)
show(plot)
# Out:
#   <div class="bk-root" id="590c9716-d83f-417a-b549-fadd7fc8725c"></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-0c9b38ac2578> in <module>()
#      16 plot.circle(x = 'Fares_sum', y = 'Fares_mean', source = data, alpha=0.5)
#      17 plot.add_tools(hover_tool)
# ---> 18 show(plot)
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/io/showing.py in show(obj, browser, new, notebook_handle, notebook_url)
#     135     if obj not in state.document.roots:
#     136         state.document.add_root(obj)
# --> 137     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     138
#     139 #-----------------------------------------------------------------------------
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/io/showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     173
#     174     if state.file or not shown:
# --> 175         _show_file_with_state(obj, state, new, controller)
#     176
#     177     return comms_handle
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/io/showing.py in _show_file_with_state(obj, state, new, controller)
#     156
#     157     '''
# --> 158     filename = save(obj, state=state)
#     159     controller.open("file://" + filename, new=NEW_PARAM[new])
#     160
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/io/saving.py in save(obj, filename, resources, title, template, state, **kwargs)
#      81
#      82     filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 83     _save_helper(obj, filename, resources, title, template)
#      84     return abspath(filename)
#      85
#
# ~/anaconda3/lib/python3.6/site-packages/bokeh/io/saving.py in _save_helper(obj, filename, resources, title, template)
#     145     html = file_html(obj, resources, title=title, template=template)
#     146
# --> 147     with io.open(filename, mode="w", encoding="utf-8") as f:
#     148         f.write(decode_utf8(html))
#     149
#
# TypeError: expected str, bytes or os.PathLike object, not Figure

# %%
df3.sort_values(by='Fares_sum', ascending=False).head(20)
# Out:
#                                  Fares_std  Fares_sum     Fares_mean
# Station
# 42ND STREET & GRAND CENTRAL  125304.509921   22140540  254488.965517
# 34TH STREET & 6TH AVENUE      63349.656684   19951575  343992.672414
# 14TH STREET-UNION SQUARE      46063.433726   18316092  631589.379310
# 42ND STREET/TIMES SQUARE      92156.533592   17150714  295701.965517
# 42ND STREET & 8TH AVENUE      89232.497539   16381207  282434.603448
# 34TH STREET & 8TH AVENUE     126063.489753   13281543  228992.120690
# 59TH STREET/COLUMBUS CIRCLE   39594.577768   12145220  418800.689655
# 59TH STREET & LEXINGTON AVE   33455.680892   10217456  176163.034483
# 86TH STREET-LEXINGTON AVE     56393.012223    9792337  337666.793103
# 47-50 STREETS/ROCKEFELLER     26950.824658    8968926  309273.310345
# 34TH STREET - PENN STATION    22568.544299    8729752  301025.931034
# PARK PLACE                    31063.620241    8409721  289990.379310
# ROOSEVELT AVE/JACKSON HTS     18530.465117    8228651  283746.586207
# MAIN STREET                   16939.804222    8117015  279897.068966
# FULTON STREET                 79653.306958    7416450  255739.655172
# WALL STREET                   17572.471941    7397141  127536.913793
# WEST 4TH ST-WASHINGTON SQ     22940.138400    7294715  251541.896552
# 8TH AVENUE-14TH STREET        25193.725793    7255448  250187.862069
# 72ND STREET & BROADWAY        19041.545547    6774687  233609.896552
# LEXINGTON AVENUE              74533.528582    6621149  114157.741379

# %%
df2.groupby(['Station', 'From Date2']).Fares.sum().reset_index()
# Out:
#                           Station From Date2  Fares
# 0      103RD ST-CENTRAL PARK WEST 2010-09-04  25986
# 1      103RD ST-CENTRAL PARK WEST 2010-09-11  28969
# 2      103RD ST-CENTRAL PARK WEST 2010-09-18  30890
# 3      103RD ST-CENTRAL PARK WEST 2011-09-03  24867
# 4      103RD ST-CENTRAL PARK WEST 2011-09-10  27087
# 5      103RD ST-CENTRAL PARK WEST 2011-09-17  24566
# 6      103RD ST-CENTRAL PARK WEST 2011-09-24  20398
# 7      103RD ST-CENTRAL PARK WEST 2012-09-01  25460
# 8      103RD ST-CENTRAL PARK WEST 2012-09-08  28363
# 9      103RD ST-CENTRAL PARK WEST 2012-09-15  27296
# 10     103RD ST-CENTRAL PARK WEST 2012-09-22  28204
# 11     103RD ST-CENTRAL PARK WEST 2013-09-07  28050
# 12     103RD ST-CENTRAL PARK WEST 2013-09-14  27849
# 13     103RD ST-CENTRAL PARK WEST 2013-09-21  28733
# 14     103RD ST-CENTRAL PARK WEST 2014-09-06  29020
# 15     103RD ST-CENTRAL PARK WEST 2014-09-13  28723
# 16     103RD ST-CENTRAL PARK WEST 2014-09-20  28535
# 17     103RD ST-CENTRAL PARK WEST 2015-09-05  26111
# 18     103RD ST-CENTRAL PARK WEST 2015-09-12  26734
# 19     103RD ST-CENTRAL PARK WEST 2016-09-03  25146
# 20     103RD ST-CENTRAL PARK WEST 2016-09-10  28686
# 21     103RD ST-CENTRAL PARK WEST 2016-09-17  27205
# 22     103RD ST-CENTRAL PARK WEST 2016-09-24  27667
# 23     103RD ST-CENTRAL PARK WEST 2017-09-02  21313
# 24     103RD ST-CENTRAL PARK WEST 2017-09-09  28978
# 25     103RD ST-CENTRAL PARK WEST 2017-09-16  27537
# 26     103RD ST-CENTRAL PARK WEST 2017-09-23  28149
# 27     103RD ST-CENTRAL PARK WEST 2018-09-01  25789
# 28     103RD ST-CENTRAL PARK WEST 2018-09-08  26286
# 29         103RD ST-ROOSEVELT AVE 2010-09-04  97294
# ...                           ...        ...    ...
# 13340                 YUKON DEPOT 2018-09-01      0
# 13341                 YUKON DEPOT 2018-09-08      0
# 13342  ZEREGA AVE-WESTCHESTER AVE 2010-09-04  12332
# 13343  ZEREGA AVE-WESTCHESTER AVE 2010-09-11  14676
# 13344  ZEREGA AVE-WESTCHESTER AVE 2010-09-18  12338
# 13345  ZEREGA AVE-WESTCHESTER AVE 2011-09-03  13834
# 13346  ZEREGA AVE-WESTCHESTER AVE 2011-09-10  15961
# 13347  ZEREGA AVE-WESTCHESTER AVE 2011-09-17  15509
# 13348  ZEREGA AVE-WESTCHESTER AVE 2011-09-24  11303
# 13349  ZEREGA AVE-WESTCHESTER AVE 2012-09-01  14278
# 13350  ZEREGA AVE-WESTCHESTER AVE 2012-09-08  16221
# 13351  ZEREGA AVE-WESTCHESTER AVE 2012-09-15  15384
# 13352  ZEREGA AVE-WESTCHESTER AVE 2012-09-22  15482
# 13353  ZEREGA AVE-WESTCHESTER AVE 2013-09-07  16826
# 13354  ZEREGA AVE-WESTCHESTER AVE 2013-09-14  16439
# 13355  ZEREGA AVE-WESTCHESTER AVE 2013-09-21  14658
# 13356  ZEREGA AVE-WESTCHESTER AVE 2014-09-06      1
# 13357  ZEREGA AVE-WESTCHESTER AVE 2014-09-13      1
# 13358  ZEREGA AVE-WESTCHESTER AVE 2015-09-05  12331
# 13359  ZEREGA AVE-WESTCHESTER AVE 2015-09-12  13190
# 13360  ZEREGA AVE-WESTCHESTER AVE 2016-09-03  12854
# 13361  ZEREGA AVE-WESTCHESTER AVE 2016-09-10  14449
# 13362  ZEREGA AVE-WESTCHESTER AVE 2016-09-17  14771
# 13363  ZEREGA AVE-WESTCHESTER AVE 2016-09-24  14734
# 13364  ZEREGA AVE-WESTCHESTER AVE 2017-09-02  12858
# 13365  ZEREGA AVE-WESTCHESTER AVE 2017-09-09  15217
# 13366  ZEREGA AVE-WESTCHESTER AVE 2017-09-16  14243
# 13367  ZEREGA AVE-WESTCHESTER AVE 2017-09-23  14670
# 13368  ZEREGA AVE-WESTCHESTER AVE 2018-09-01  13047
# 13369  ZEREGA AVE-WESTCHESTER AVE 2018-09-08  13733
#
# [13370 rows x 3 columns]

# %%
# Out:
# ['WHITEHALL STREET',
#  'CYPRESS HILLS',
#  '75TH STREET & ELDERTS LANE',
#  '85TH STREET & FOREST PKWAY',
#  'WOODHAVEN BOULEVARD',
#  '104TH STREET',
#  '111TH STREET',
#  '121ST STREET',
#  '42ND STREET & 8TH AVENUE',
#  '34TH STREET & 8TH AVENUE',
#  'FULTON STREET',
#  'FIFTH AVENUE',
#  'LEXINGTON AVENUE',
#  'ROOSEVELT AVE/JACKSON HTS',
#  '179TH STREET & HILLSIDE AVE',
#  '47-50 STREETS/ROCKEFELLER',
#  '42ND STREET & 6TH AVENUE',
#  '34TH STREET & 6TH AVENUE',
#  'SUTPHIN BOULEVARD',
#  'JAMAICA CENTER-PARSONS BLVD',
#  'WALL STREET',
#  'FULTON & WILLIAM STREETS',
#  'PARK PLACE',
#  'CHAMBERS STREET',
#  '34TH STREET & 7TH AVENUE',
#  '42ND STREET/TIMES SQUARE',
#  '125TH STREET & BROADWAY',
#  '168TH STREET & BROADWAY',
#  'DYCKMAN STREET',
#  '207TH STREET',
#  '215TH STREET',
#  '225TH STREET',
#  '231ST STREET',
#  'BOWLING GREEN & BATTERY PL',
#  'BOWLING GREEN & BROADWAY',
#  'BROOKLYN BRIDGE',
#  '42ND STREET & GRAND CENTRAL',
#  '42ND STREET & 3RD AVENUE',
#  '51ST STREET & LEXINGTON AVE',
#  '59TH STREET & LEXINGTON AVE',
#  'WOODLAWN ROAD',
#  '149TH STREET & 3RD AVENUE',
#  'FIFTH AVENUE & 42ND STREET',
#  'MAIN STREET',
#  'NEVINS STREET',
#  'BARCLAYS CENTER',
#  'BERGEN STREET',
#  'GRAND ARMY PLAZA',
#  'EASTERN PARKWAY',
#  'NOSTRAND AVENUE',
#  'UTICA AVENUE',
#  'SUTTER AVENUE',
#  'SARATOGA AVENUE',
#  'JUNIUS STREET',
#  'PENNSYLVANIA AVENUE',
#  'NEW LOTS AVENUE',
#  'ST GEORGE TERMINAL',
#  '34TH STREET - HUDSON YARDS',
#  'FIFTH AVENUE & 60TH STREET',
#  '57TH STREET & 7TH AVENUE',
#  '49TH STREET & 7TH AVENUE',
#  '28TH STREET & BROADWAY',
#  '23RD STREET & 5TH AVENUE',
#  '59TH STREET/COLUMBUS CIRCLE',
#  '8TH STREET & BROADWAY',
#  'PRINCE STREET & BROADWAY',
#  'CITY HALL',
#  'CORTLANDT STREET',
#  'JAY ST-METROTECH',
#  '39TH AVENUE & 31ST STREET',
#  '36TH AVENUE & 31ST STREET',
#  'BROADWAY & 31ST STREET',
#  '30TH AVENUE & 31ST STREET',
#  'ASTORIA BLVD & 31ST STREET',
#  'DITMARS BLVD & 31ST STREET',
#  '82ND STREET-JACKSON HEIGHTS',
#  'JUNCTION BLVD-ROOSEVELT AVE',
#  'CHURCH AVENUE',
#  'DEKALB AVENUE',
#  'METROPOLITAN AVENUE',
#  '145TH STREET',
#  '125TH STREET',
#  'BROADWAY-EAST NEW YORK',
#  '167TH ST-GRAND CONCOURSE',
#  '14TH STREET & 7TH AVENUE',
#  'CASTLE HILL AVENUE',
#  'WESTCHESTER SQUARE',
#  'BOROUGH HALL - COURT STREET',
#  'CHURCH AVENUE & NOSTRAND AV',
#  'FLATBUSH AVE & NOSTRAND AV',
#  '23RD STREET & 8TH AVENUE',
#  'FORDHAM RD/GRAND CONCOURSE',
#  'SEVENTH AVENUE & WEST 53RD',
#  'PARSONS BLVD & HILLSIDE AV',
#  '169TH STREET & HILLSIDE AVE',
#  '50TH STREET & 7TH AVENUE',
#  '242ND STREET & BROADWAY',
#  'CANAL STREET',
#  'FORDHAM ROAD & JEROME AVE',
#  'MORRISON AVE & WESTCHESTER',
#  'QUEENSBORO PLAZA',
#  '90TH STREET/ELMHURST AVENUE',
#  'FRANKLIN AVE/EASTERN PKWY',
#  'KINGSTON AVE/EASTERN PKWY',
#  'BROAD STREET & WALL STREET',
#  '175TH STREET/FT WASHINGTON',
#  'SUTPHIN BLVD-HILLSIDE AVE',
#  'BERGEN STREET-SMITH STREET',
#  'KINGS HIGHWAY-MCDONALD AVE',
#  '23RD STREET-PARK AVE SOUTH',
#  '125TH STREET-LEXINGTON AVE',
#  'MOSHOLU PARKWAY-JEROME AVE',
#  'HUNTERS PT AVE-49TH AVE',
#  'NEWKIRK AVE-NOSTRAND AVE',
#  'SHEEPSHEAD BAY ROAD',
#  'MYRTLE AVE-GATES AVENUE',
#  'WEST 4TH ST-WASHINGTON SQ',
#  'CANAL STREET-LISPENARD ST',
#  'QUEENS PLAZA-JACKSON AVE',
#  '71ST AVE-CONTINENTAL AVE',
#  'ESSEX ST-DELANCEY ST',
#  '28TH STREET-PARK AVE SOUTH',
#  '96TH STREET-LEXINGTON AVE',
#  '241ST ST-WHITE PLAINS RD',
#  'HUNTS PT AVE-SOUTHERN BLVD',
#  '61ST STREET-ROOSEVELT AVE',
#  'PARKSIDE AVE-OCEAN AVE',
#  'NEWKIRK PLAZA',
#  'AVENUE U-EAST 16TH STREET',
#  'STILLWELL AVE-CONEY ISLAND',
#  'ROCKAWAY PKWY-GLENWOOD RD',
#  'UTICA AVE-STUYVESANT AVE',
#  'TREMONT AVE-179TH ST',
#  'KINGSBRIDGE RD-196TH ST',
#  'BEDFORD PARK BLVD-203RD ST',
#  '205TH ST-BAINBRIDGE AVE',
#  'UNION TURNPIKE-KEW GARDENS',
#  '116TH STREET-COLUMBIA',
#  'ASTOR PLACE-4 AVENUE',
#  'KINGSBRIDGE RD-JEROME AVE',
#  'ELDER AVE-WESTCHESTER AVE',
#  '14TH STREET-6TH AVENUE',
#  '66TH STREET-BROADWAY',
#  'TOMPKINSVILLE',
#  '79TH STREET-BROADWAY',
#  '86TH STREET-BROADWAY',
#  '96TH STREET-BROADWAY',
#  '137TH STREET-BROADWAY',
#  '14TH STREET-UNION SQUARE',
#  '7TH AVENUE-PARK PLACE',
#  'BRIGHTON BEACH-CONEY ISLAND',
#  '207TH STREET-BROADWAY',
#  '181ST STREET-FT WASH AVE',
#  '8TH AVENUE-14TH STREET',
#  '33RD STREET-PARK AVENUE',
#  '68TH STREET-HUNTER COLLEGE',
#  '77TH STREET-LEXINGTON AVE',
#  '86TH STREET-LEXINGTON AVE',
#  '103RD STREET-LEXINGTON AVE',
#  '110TH STREET-LEXINGTON AVE',
#  '116TH STREET-LEXINGTON AVE',
#  'BEDFORD PARK BLVD-JEROME AV',
#  'CORTELYOU RD-EAST 16TH ST',
#  'DYCKMAN STREET-BROADWAY',
#  '86TH ST-CENTRAL PARK WEST',
#  '81ST STREET-MUSEUM',
#  '50TH STREET-8TH AVENUE',
#  'CHRISTOPHER ST-SHERIDAN SQ',
#  '23RD STREET-7TH AVENUE',
#  '103RD STREET-BROADWAY',
#  '110TH STREET-BROADWAY',
#  '157TH STREET-BROADWAY',
#  'BLEECKER ST-LAFAYETTE ST',
#  '161ST STREET-YANKEE STADIUM',
#  'PROSPECT PARK-EMPIRE BLVD',
#  '36TH STREET-4TH AVENUE',
#  'NOSTRAND AVE-FULTON ST',
#  'KINGSTON AVE-THROOP AVE',
#  'EUCLID AVE-PITKIN AVE',
#  'WOODHAVEN BLVD-QUEENS BLVD',
#  '63RD DRIVE-REGO PARK',
#  '23RD STREET-6TH AVENUE',
#  'CHURCH AVE-MCDONALD AVE',
#  '149TH ST-GRAND CONCOURSE',
#  '125TH STREET-LENOX AVENUE',
#  '135TH STREET-LENOX AVENUE',
#  '103RD ST-ROOSEVELT AVE',
#  'STERLING ST-NOSTRAND AVE',
#  'BEVERLY RD-NOSTRAND AVE',
#  'KINGS HIGHWAY-EAST 16TH ST',
#  '59TH STREET-4TH AVENUE',
#  'BAY RIDGE AVE-4TH AVENUE',
#  '77TH STREET-4TH AVENUE',
#  '86TH STREET-4TH AVENUE',
#  'BAY RIDGE - 95TH STREET',
#  'HOYT ST-SCHERMERHORN ST',
#  'ELMHURST AVE-BROADWAY',
#  '67TH AVENUE-QUEENS BLVD',
#  'CARROLL ST-PRESIDENT ST',
#  '167TH STREET-RIVER AVENUE',
#  '177TH STREET-PARKCHESTER',
#  '46TH ST-BLISS ST',
#  'CLARK STREET-HENRY STREET',
#  'HOYT STREET-HOYT STREET',
#  'GUN HILL ROAD-SEYMOUR',
#  'RECTOR STREET-CHURCH STREET',
#  'AVENUE J-EAST 16TH STREET',
#  'AVENUE M-EAST 16TH STREET',
#  'NECK ROAD-EAST 16TH STREET',
#  'UNION STREET-4TH AVENUE',
#  '45TH STREET-4TH AVENUE',
#  '53RD STREET-4TH AVENUE',
#  '50TH STREET-NEW UTRECHT AVE',
#  'BEDFORD AVE-NORTH 7TH ST',
#  'DEKALB AVE-WYCKOFF AVE',
#  '182ND STREET-183RD STREET',
#  'STEINWAY ST-BROADWAY',
#  'GREENPOINT AVE',
#  'GRAND ST-CHRISTIE ST',
#  '15TH ST-PROSPECT PARK WEST',
#  '18TH AVE-MCDONALD AVE',
#  '170TH STREET-JEROME AVENUE',
#  'BURNSIDE AVE-JEROME AVE',
#  'ST LAWRENCE AVE-WEST AVE',
#  'PROSPECT AVENUE-4TH AVENUE',
#  '55TH ST-NEW UTRECHT AVE',
#  '1ST AVENUE-14TH STREET',
#  'GRAHAM AVE-METROPOLITAN AVE',
#  'GRAND ST-BUSHWICK AVE',
#  '96TH ST-CENTRAL PARK WEST',
#  'HIGH ST-CADMAN PLAZA WEST',
#  '174TH-175TH ST-GRAND CONCOU',
#  'GRAND AVE-QUEENS BOULEVARD',
#  'VAN WYCK BLVD-MAIN STREET',
#  'NASSAU AVE-MANHATTAN AVE',
#  'EAST BROADWAY-MADISON ST',
#  '4TH AVENUE-9TH STREET',
#  'ROOSEVELT ISLAND',
#  '181ST STREET-ST NICHOLAS AV',
#  '40TH STREET-LOWERY STREET',
#  'BEVERLEY ROAD -EAST 15TH ST',
#  'AVENUE H-EAST 16TH STREET',
#  'OCEAN PKWAY-BRIGHTON BCH AV',
#  'MONTROSE AVENUE',
#  'HALSEY STREET-WYCKOFF AVE',
#  '46TH STREET-BROADWAY',
#  'METROPOLITAN AVE-LORIMER ST',
#  'BEDFORD AVENUE-NOSTRAND AVE',
#  'SMITH STREET-9TH STREET',
#  'AVENUE X-MCDONALD AVENUE',
#  '28TH STREET-7TH AVENUE',
#  '145TH STREET-BROADWAY',
#  '191ST STREET-ST NICHOLAS AV',
#  '183RD STREET-JEROME AVENUE',
#  'JACKSON AVENUE-VERNON BLVD',
#  'PRESIDENT ST-NOSTRAND AVE',
#  '25TH STREET-4TH AVENUE',
#  'JEFFERSON STREET-WYCKOFF AV',
#  '190TH STREET-OVERLOOK TERR',
#  '72ND STREET-CENTRAL PK WEST',
#  'SPRING STREET-6TH AVENUE',
#  'LAFAYETTE AVENUE-FULTON ST',
#  'CLINTON AVENUE-FULTON ST',
#  'MOTT AVENUE-BEACH 22ND ST',
#  'MYRTLE AVENUE-MARCY AVENUE',
#  'CLASSON AVENUE-LAFAYETTE AV',
#  '7TH AVENUE-9TH STREET',
#  'FT HAMILTON PKY-GREENWOOD',
#  'HOUSTON STREET-VARICK ST',
#  '33RD STREET-QUEENS BLVD',
#  'BAYCHESTER AVE-TILLOTSON',
#  '34TH STREET - PENN STATION',
#  'MORGAN AVENUE-HARRISON PL',
#  'WILSON AVENUE-MOFFAT STREET',
#  '163RD ST & AMSTERDAM AVE',
#  'FRANKLIN AVENUE-FULTON ST',
#  'NORTHERN BLVD-BROADWAY',
#  'BROADWAY - UNION AVENUE',
#  '2ND AVENUE-HOUSTON STREET',
#  'YORK STREET-JAY STREET',
#  '57TH STREET-6TH AVENUE',
#  '21ST STREET-QUEENSBRIDGE',
#  'RECTOR STREET-GREENWICH ST',
#  '238TH STREET-BROADWAY',
#  '138TH ST-GRAND CONCOURSE',
#  'MT EDEN AVENUE-JEROME AVE',
#  '176TH STREET-JEROME AVENUE',
#  '111TH STREET-ROOSEVELT AVE',
#  'BOWERY STREET-DELANCEY ST',
#  'WEST 6TH STREET-SURF AVENUE',
#  'BUSHWICK AVENUE-ABERDEEN ST',
#  '103RD ST-CENTRAL PARK WEST',
#  '155TH STREET-8TH AVENUE',
#  'FLUSHING AVENUE-MARCY AVE',
#  'LAFAYETTE AV-WASHINGTON AV',
#  'FULTON STREET-LAFAYETTE AV',
#  '63RD STREET-LEXINGTON AVE',
#  'CANAL STREET-VARICK STREET',
#  '18TH STREET-7TH AVENUE',
#  'SPRING STREET-LAFAYETTE ST',
#  '111TH STREET-LENOX AVENUE',
#  '116TH STREET-LENOX AVENUE',
#  'WHITLOCK AVE-WESTCHESTER AV',
#  'ZEREGA AVE-WESTCHESTER AVE',
#  '52ND STREET-ROOSEVELT AVE',
#  'WILLETS PT BLVD-ROOSEVELT',
#  'MORRIS PARK-PAULDING AVENUE',
#  '3RD AVENUE-14TH STREET',
#  '155TH STREET-ST NICHOLAS AV',
#  '135TH STREET-ST NICHOLAS AV',
#  '116TH STREET-8TH AVENUE',
#  '110TH STREET-8TH AVENUE',
#  'GASTON AVENUE-BEACH 67TH ST',
#  'STRAITON AVE-BEACH 60TH ST',
#  'FRANK AVENUE-BEACH 44TH ST',
#  'EDGEMERE-BEACH 36TH STREET',
#  '36TH STREET-NORTHERN BLVD',
#  '65TH STREET-BROADWAY',
#  '75TH AVENUE-QUEENS BLVD',
#  'VAN WYCK BLVD-METROPOLITAN',
#  'FRANKLIN STREET-WEST BWAY',
#  '145TH STREET-LENOX AVENUE',
#  '148TH STREET-LENOX AVENUE',
#  'COURT SQ',
#  '69TH STREET-ROOSEVELT AVE',
#  'ATLANTIC AV-VAN SINDEREN AV',
#  'SUTTER AVE-VAN SINDEREN AVE',
#  'LIVONIA AVE-VAN SINDEREN AV',
#  'HEWES STREET-BROADWAY',
#  'LORIMER STREET-BROADWAY',
#  '104TH STREET-LIBERTY AVENUE',
#  '109TH STREET-LIBERTY AVENUE',
#  'LEFFERTS BLVD-LIBERTY AVE',
#  'NORTH CONDUIT AVE-COHANCEY',
#  'BEACH 25TH STREET-WAVECREST',
#  'COURT SQ-23 ST',
#  '21ST STREET-JACKSON AVENUE',
#  'PELHAM PKWY-WHITE PLAINS RD',
#  'ALLERTON AV-WHITE PLAINS RD',
#  'BURKE AVE-WHITE PLAINS ROAD',
#  'GUNHILL RD-WHITE PLAINS RD',
#  '219TH ST-WHITE PLAINS ROAD',
#  '225TH ST-WHITE PLAINS ROAD',
#  '233RD ST-WHITE PLAINS ROAD',
#  '9TH AVENUE-39TH STREET',
#  'FORT HAMILTON PKWY-45TH ST',
#  '71ST STREET-NEW UTRECHT AVE',
#  '79TH STREET-17TH AVENUE',
#  '18TH AVENUE-86TH STREET',
#  '20TH AVENUE-86TH STREET',
#  'BAY PARKWAY-86TH STREET',
#  'NEW LOTS AV-VAN SINDEREN AV',
#  'EAST 105TH ST-FARRAGUT ROAD',
#  'FLUSHING AVE-BROADWAY',
#  'MYRTLE AVENUE-BROADWAY',
#  'KOSCIUSZKO STREET-BROADWAY',
#  'GATES AVENUE-BROADWAY',
#  'HALSEY STREET-BROADWAY',
#  'GRANT AVENUE-PITKIN AVENUE',
#  'HUDSON STREET-78TH STREET',
#  'BOYD STREET-88TH STREET',
#  'ROCKAWAY BLVD-LIBERTY AVE',
#  '174TH STREET-SOUTHERN BLVD',
#  'EAST TREMONT AVENUE-178 ST',
#  'EAST 180TH ST-MORRIS PARK',
#  'BRONX PARK EAST',
#  '8TH AVENUE-62ND STREET',
#  'FORT HAMILTON PARKWAY-62ND',
#  '18TH AVENUE-62ND STREET',
#  '20TH AVENUE-62ND STREET',
#  'BAY PARKWAY-66TH STREET',
#  'KINGS HIGHWAY-WEST 7TH ST',
#  'AVENUE U-WEST 7TH STREET',
#  '86TH STREET-AVENUE V',
#  'NEW UTRECHT AVENUE-62ND ST',
#  '25TH AVENUE-86TH STREET',
#  'BAY 50TH STREET-STILLWELL',
#  'CENTRAL AVE-MYRTLE AVE',
#  'SENECA AVENUE-PALMETTO ST',
#  'FOREST AVENUE-PUTNAM AVENUE',
#  'FRESH POND ROAD-68TH AVENUE',
#  'JACKSON AVENUE-WESTCHESTER',
#  'PROSPECT AVENUE-WESTCHESTER',
#  'INTERVALE 163RD STREET',
#  'SIMPSON ST-WESTCHESTER AVE',
#  'FREEMAN ST-SOUTHERN BLVD',
#  'PARK PLACE-FRANKLIN AVENUE',
#  'BOTANIC GARDEN-FRANKLIN AVE',
#  'KNICKERBOCKER AVE-MYRTLE AV',
#  'HOWARD BEACH-159TH AVE',
#  'BROAD CHANNEL-NOEL ROAD',
#  'HOLLAND-BEACH 90TH STREET',
#  'PLAYLAND-BEACH 98TH STREET',
#  'SEASIDE BEACH-105TH STREET',
#  'ROCKAWAY PARK-BEACH 116TH',
#  'DITMAS AVE-MCDONALD AVE',
#  'AVENUE I-MCDONALD AVENUE',
#  'MCDONALD AVE-22ND AVE',
#  'AVENUE N-MCDONALD AVENUE',
#  'AVENUE P-MCDONALD AVENUE',
#  'AVENUE U-MCDONALD AVENUE',
#  'NEPTUNE AVE-MCDONALD AVENUE',
#  'MIDDLETOWN ROAD-WESTCHESTER',
#  'BUHRE AVE-WESTCHESTER AVE',
#  'PELHAM BAY PARK-BRUCKNER BL',
#  'PELHAM PKWY-ESPLANADE',
#  'DYRE AVENUE-LIGHT STREET',
#  'CHAUNCEY STREET-ROCKAWAY AV',
#  'ALABAMA AVENUE-FULTON ST',
#  'VAN SICLEN AVENUE-FULTON ST',
#  'CLEVELAND STREET-FULTON ST',
#  'NORWOOD AVENUE-FULTON ST',
#  'CRESCENT STREET-FULTON ST',
#  'RALPH AVENUE-FULTON STREET',
#  'ROCKAWAY AVE-HOPKINSON AVE',
#  'LIBERTY AVE-PENNSYLVANIA AV',
#  'VAN SICLEN AVE-PITKIN AVE',
#  'SHEPHERD AVE-PITKIN AVE',
#  '170TH STREET-GRAND CONC.',
#  '238TH ST-WHITE PLAINS ROAD',
#  '138TH STREET-3RD AVE',
#  'BROOK AVENUE-138TH STREET',
#  'CYPRESS AVENUE-138TH STREET',
#  'EAST 143RD ST-SOUTHERN BLVD',
#  'EAST 149TH ST-SOUTHERN BLVD',
#  'LONGWOOD AVE-SOUTHERN BLVD',
#  'WINTHROP ST-NOSTRAND AVE',
#  '72ND STREET & BROADWAY',
#  'PROSPECT AVE-4TH AVE',
#  'HOYT STREET-FULTON STREET',
#  'ORCHARD BEACH',
#  'MARCY AVENUE-BROADWAY',
#  'BROADWAY LAFAYETTE-BLEECKER',
#  'CANAL STREET-BROADWAY',
#  'CANAL ST-LAFAYETTE ST EAST',
#  'AQUEDUCT RACE TRACK',
#  'RI TRAMWAY (MANHATTAN)',
#  'RI TRAMWAY (ROOSEVELT)',
#  'AIRTRAIN @ HOWARD BEACH',
#  'AIRTRAIN JAMAICA CENTER 1',
#  'PA-PATH WORLD TRADE CNTR',
#  'PA-PATH THIRTY THIRD ST',
#  'PA-PATH TWENTY THIRD ST',
#  'PA-PATH EXCHANGE PLACE',
#  'PA-PATH HARRISON',
#  'PA-PATH 14TH STREET',
#  'PA-PATH PAVONIA/NEWPORT',
#  'PA-PATH 9TH STREET',
#  'PA-PATH CHRISTOPHER ST',
#  'PA-PATH NEWARK',
#  'PA-PATH HOBOKEN',
#  'PA-PATH GROVE ST',
#  'PA-PATH JOURNAL SQUARE',
#  'ROCKAWAY AVENUE',
#  'VAN SICLEN AVENUE',
#  'FULTON ST & BROADWAY NASSAU',
#  'ATLANTIC AVENUE',
#  'NEWKIRK AVE-EAST 16TH ST',
#  'ROCKWAY AVENUE',
#  '241TH ST-WHITE PLAINS RD',
#  '45TH ROAD-COURT HOUSE SQ',
#  '23RD STREET-ELY AVENUE',
#  'KOSCIUSKO STREET-BROADWAY',
#  'GRANT AVNUE-PITKIN AVENUE',
#  'SHEPERD AVE-PITKIN AVE',
#  'SOUTH FERRY',
#  'CASTLETON DEPOT',
#  'GRAND AVENUE DEPOT',
#  'GUNHILL DEPOT',
#  'YUKON DEPOT',
#  'QUEENS VILLAGE DEPOT',
#  'CASEY STENGEL DEPOT',
#  'JAMAICA DEPOT',
#  'FRESH POND DEPOT',
#  'EAST NEW YORK DEPOT',
#  'JACKIE GLEASON DEPOT',
#  'FLATBUSH DEPOT',
#  'ULMER PARK DEPOT',
#  'KINGSBRIDGE DEPOT',
#  'JACKIE GLEASON DEPOT(2)',
#  'MOTHER CLARA HALE DEPOT',
#  'MANHATTANVILLE DEPOT',
#  'CHARLESTON DEPOT',
#  'WEST FARMS DEPOT',
#  'MICHAEL J. QUILL DEPOT',
#  'TUSKEGEE AIRMEN DEPOT',
#  'MTABC - LA GUARDIA DEPOT',
#  'MTABC - COLLEGE POINT DEPOT',
#  'MTABC - JFK DEPOT',
#  'MTABC - FAR ROCKAWAY DEPOT',
#  'MTABC - SPRING CREEK DEPOT',
#  'MTABC - BAISLEY DEPOT',
#  'MITCHELL FIELD BUS DEPOT',
#  'WESTCHESTER CMF YONKERS DEPOT',
#  'WESTCHESTER VALHALLA DEPOT',
#  'MTABC - COLLEGE POINT DEPOT2*',
#  'SBS-M15 @ LIVINGSTON PLAZA',
#  'SBS-BX12 @ LIVINGSTON PLAZA',
#  'SBS-M34 @ LIVINGSTON PLAZA',
#  'SBS-BX41 @ LIVINGSTON PLAZA',
#  'SBS-B44 @ LIVINGSTON PLAZA',
#  'SBS-M60 @ LIVINGSTON PLAZA',
#  'SBS-M86 @ LIVINGSTON PLAZA',
#  'MTABC - EASTCHESTER 2',
#  'SBS-B46 @ LIVINGSTON PLAZA',
#  'SBS-Q44 @ LIVINGSTON PLAZA',
#  'SBS-M23 @ LIVINGSTON PLAZA',
#  'SBS-M79 @ LIVINGSTON PLAZA',
#  'SBS-BX6 @ LIVINGSTON PLAZA',
#  '72ND STREET - 2 AVENUE',
#  '86TH STREET - 2 AVENUE',
#  '96TH STREET - 2 AVENUE',
#  'MTABC - EASTCHESTER DEPOT',
#  'CORTLANDT ST-WORLD TRADE CT',
#  'SBS-Q52/53 @ LIVINGSTON PLAZA']

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.plotting import ColumnDataSource
from bokeh.models import HoverTool

output_notebook()

stations = list(df2['Station'].unique())

hover_tool = HoverTool(tooltips =[
    ('Station', '@Station'),
    ('Total Fares', '@Fares'),
    ('Date','@{From Date2}')
])

plot = figure()
for station in stations:
    data = ColumnDataSource(df2[df2['Station']==station])
    plot.circle(x = 'From Date2', y = 'Fares', source = data, alpha=0.2, hover_fill_color="firebrick", hover_alpha=0.5)
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d2c094d8-7d07-41f0-9b5c-0664b6242abf">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-5430bab061b9> in <module>()
#      16     data = ColumnDataSource(df2[df2['Station']==station])
#      17     cr = plot.circle(x = 'From Date2', y = 'Fares', source = data, alpha=0.2, hover_fill_color="firebrick", hover_alpha=0.5)
# ---> 18 plot.add_tools(hover_tool, renderers=[cr])
#      19 show(plot)
#
# TypeError: add_tools() got an unexpected keyword argument 'renderers'
